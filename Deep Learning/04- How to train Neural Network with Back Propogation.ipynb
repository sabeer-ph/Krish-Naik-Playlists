# %% [markdown]
# Today we will try to understand Neural Network Training with back and forward propogation. We will also try to understand the concept of loss function optimizer.

# %% [markdown]
# ![04%20train%20data.PNG](attachment:04%20train%20data.PNG)
#
# So we have training data where a student spends time on each activity and the output 1 says he passed the exam (if 0 the failed). So with this data lets try to understand how a neural network will be trained.

# %% [markdown]
# **Forward Propogation**
#
# Input Layer : We have 3 inputs play, study and sleep we named it as X1,X2,X3. This along with the weights W1,W2,W3 is transfererd to the hidden layer
#
# Hidden Layer : below 2 steps are done and the output (z) is passed on to output layer with weight w4
#                 * sum of all input * weights + bias --> y
#                 * activation function on the output act(y) --> z
#
# Output layer : Will return the predicated output (y^ called y hat)

# %% [markdown]
# From the training data we already know that the output is 1 but lets suppose the predicated output from the neural network is zero. Next step is the compare y and y^ to see if it same. the difference of the 2 value can be calculated using **Loss Function** and the formula for the same is shown below.
#
# ![04%20Loss%20function.PNG](attachment:04%20Loss%20function.PNG)
#
# **Note** : The reason we have square is because if output is 0 and predicated value is 1 then it will be 0 - 1 = -1 . Hence to get a +ve number we do the squrring
#
# In our case the loss value is (1 - 0)*2 which is 1. The loss function value is 1 and its high. Our AIm is to reduced the loss and we have to reduced it to a minimal value such that our y and y^ should be equal (almost equa;l) and in order to achive that we will be updating the weights.
#
# The process of reducing the loss function is called **optimzer**. There are lot of optimzers in deep learning some of them **Gradient Descent** and **shockastic Gradient Descent**

# %% [markdown]
# So what hapens next. We have loss value and the optimizer will try to reduce the loss function. In order to reuce the loss function we need to back propogate and back progagte means we have to update the weights.
#
# **BAck Propogation :** Here will be going back from the output to input and in the first step we try to update W4. The new W4 is calulated as below
#
# ![04%20new%20weight.PNG](attachment:04%20new%20weight.PNG)
#
# the learning rate should be a small value as it will helo us to reach the Global Minima point.
#
# Next Once we have calulate w4 then we calualte the new weights of W1, W2, W3 with the same formula. Once we have calulate the new values for all weights then we do forward propogation with newly calculated values. This process of forward and backward propagtion will continue for some number of **epochs** until the loss value is completly reduced. Once it reduced we can see that y and y^ will be matching.

# %% [markdown]
# Since in our example we had only one row we calculated loss function but when we have multiple rows then we have calculate **Cost Function**.
#
# ![04%20cost%20function.PNG](attachment:04%20cost%20function.PNG)

# %% [markdown]
# Picture for back and forward propogation with black for forwrd and red for backward
#
# ![04%20Back%20&%20Forward.PNG](attachment:04%20Back%20&%20Forward.PNG)
