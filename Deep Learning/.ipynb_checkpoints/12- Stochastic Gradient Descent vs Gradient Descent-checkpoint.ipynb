# %% [markdown]
# In this section we will try to  understand what exactly is gradient descent and stochastic  gradient descent. what is the exact  difference between this SGD and the  gradient descent.
#
# During the backpropogation the formula used to update the weights is as shown below
#
# ![12%20Gradient%20Descent.PNG](attachment:12%20Gradient%20Descent.PNG)
#
# gradient descent is one function  which will have this kind of shape. if we have a point an we draw a tangent line through it and if the right side is downloards then is -ve. If its -ve then we have to increase the weight to reach the global minina and vice versa. (drawing a line means finding the derivative of the point). unless and until we reach the global minima it means we havent got the right weight to reach it.

# %% [markdown]
# let us go back to our formula of updating weights in this particular formula  the most important thing that we need to find out is the derivative of loss with respect to derivative of w old.
#
# ![12%20GD-SGD-%20Batch%20SGD.PNG](attachment:12%20GD-SGD-%20Batch%20SGD.PNG)
#
# if we consider  all the data points lets say we considering all the N points suppose in dataset we  have thousand records, consider all the thousand data  point to solve  this particular derivative of loss with  respect to this particular weight is called  as **gradient descent**
#
#
# trying to find out this  derivative of loss considering only one data point is called  as **stochastic radient descent**
#
# suppose we  consider where K data points where K is less than and  N (Total Data points) it called as  **mini-batch stochastic gradient descent**
#
#
# Note : Gradient descent is one used to solve the Linear Regression in machine learning

# %% [markdown]
# **now why do we require to do mini-batches ?** - Lets imagine we are  solving using gradient descent the data set is having million records the amount  of computation that will be  requiring to load the whole 1 million  records in order to prevent that we use  mini-batch stochastic gradient descent.
#
# **Problems faced if we used Mini Batch GD** :
#
# ![12%20Mini%20Batch%20SGD%20Problem.PNG](attachment:12%20Mini%20Batch%20SGD%20Problem.PNG)
#
# In the above graph the centre is the global minima and we have 2 weights W1 & W2 and we use  2 menthods GD and Mini Batch SGD. Using GD  convergence will happen like a stright line. But when are taking sample of data points so  the convergence will not happen quickly  you know the convergence will have some  zigzag manner it will take time to reach the convergence
#
# the derivative of loss with respect to  derivative of the old with mini-batch mini-batch SGD will be approximately  equal to derivative of loss with respect  to derivative of the weight old with  respect to gradient descent.  **approximately equal it will  never be equal**. So mini batch takes more time and GD is computation intensive.
#
# statistical we can say **GD is populaion and mini batch as sample** and if we find out the mean and  average of a population with  respect to the sample mean this will  be approximately equal it will not be exactly equal.
#
# The zigzag  movement is basically called as a noise  it is basically called as a noisy data  you know it has some noise now in order  to remove this noise there is a concept  called a stochastic gradient descent  with momentum
