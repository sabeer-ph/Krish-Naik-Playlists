# %% [markdown]
# we will try to understand Adaptive gradient descent (Adagrad) Optimizers in Neural Network

# %% [markdown]
# In the previous section we learnt other optimers like GD, SGD and Mini Batch SGD and we also saw the formula for updating weight i.e Wnew = wold - learning rate ( d loss / d W old) we will make small chnages to this formual and we write it as
#
# ![15%20weight%20update%20formual.PNG](attachment:15%20weight%20update%20formual.PNG)
#
# Note : where t is current iteration and t-1 is previous

# %% [markdown]
# The idea behind Adagrad Optimizers is to use diffent Learning rate for each and every neurons and hidden layers  based on different iterations.

# %% [markdown]
# Since the learning rate needs to be changed we have a new weight updating formual with a new vatibale for learning rate
#
# ![15%20Adagrad.PNG](attachment:15%20Adagrad.PNG)
#
# the new learning rate for each iteration formula is as below

# %% [markdown]
# ![15%20New%20learning%20rate.PNG](attachment:15%20New%20learning%20rate.PNG)
#
# here Ɛ is very small +ve numbers i.e (i.e if ∝t = 0 then the denominator will be still not be zero)
#
# **Note :** ∝t is calculate for every iteration and for every iteration is increase and becomes a bigger number (also its squarred). Because the denominator increases on every iteration then the division will give a smaller learning rate for increasing itertaion

# %% [markdown]
# Since the learning rate is decreasing on the curve we can see that intially the weight updates are higher and gradually it decreases reaching the global minima.
#
# ![15%20Achieving%20GM.PNG](attachment:15%20Achieving%20GM.PNG)

# %% [markdown]
# **Disadvantage :** Since the ∝t formual has a square the more the number of iteration the value will be become very high.
#
# How to fix it we will see in the next section
