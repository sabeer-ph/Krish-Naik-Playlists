# %% [markdown]
# In this lesson we will try to understand what and why Vanishing Gradient problem.
#
#
# ![07%20Vanishing%20Gradient.PNG](attachment:07%20Vanishing%20Gradient.PNG)
#
# Vanishing Gradient problem happens specific to sigmoid function. Evnthough we know that sigmoid activation function trasnltes data between 0 and 1 but whilte calculating the derivative of new weights in the back propogation the derivative of sigmoid function range only between **0 and 0.25**.

# %% [markdown]
# ![07%20Sigmoid%20derivative.PNG](attachment:07%20Sigmoid%20derivative.PNG)
#
# In the sigmoid graph we can see that the value ranges from 0 to 1 and the red line which is the derivative of the sigmoid range between 0 to 0.25.
#
#
# Because the value ranges from 0 to 0.25 while calculating the derivative and if we have many hidden layer multipying many value with point gives us a very small value. replacing this derivavtive value in the new weight caclulating formual which is
# new weight = old weight - learning rate * derivative . since the derivative is small and also the learning rate, this value is so small and negligible hence the value new weight is same as old weight and it doesnt not change.
#
# So in the 80's before ReLu was invented people dint use neural network with many layers max one to 3 layers were used.
