# %% [markdown]
# In todays section we will try to understand what is the better way to initialize weights and what are the technique reserchers use with respect to weight intialization.

# %% [markdown]
# ![11%20Weight%20Initialization.PNG](attachment:11%20Weight%20Initialization.PNG)
#
# If the weight is very small then we will face gradient descent problem.
# if we give the same input like zero then output will be zero.
# if we give same weights and input to 2 diff neuron then their learning will be same

# %% [markdown]
# ![11%20Names.PNG](attachment:11%20Names.PNG)
#
# Names used for neuron inputs and outputs as per resercher papers

# %% [markdown]
# Next we will learn about the weight intialization techniques.
#
# ![11%20Unform%20Distribution.PNG](attachment:11%20Unform%20Distribution.PNG)
#
# In this weights are selected from uniform distruction using the formual with the range specified. If we have 3 inputs then our range will be between -1/sqrt(3) to 1/sqrt(3). Works well with sigmoid activation function.

# %% [markdown]
# ![11%20Xavier%20&%20Gorat.PNG](attachment:11%20Xavier%20&%20Gorat.PNG)
#
# Under Xavier & Gorat Intitiaztion technique there are 2 types.
#
#     * Xavier / Gorat Normal - where weights are taken from Normal Distribution with Mean 0 and SD/variance of sigma
#     * Xavier / Gorat Uniform -- where weights are taken from Uniform Distribution with the formula shown
#
# Works well with sigmoid activation function.

# %% [markdown]
# ![11%20He%20Init.PNG](attachment:11%20He%20Init.PNG)
#
# This works well with ReLu Activation function
