# %% [markdown]
# **Epoch :** With All the data doing a forward ppropogation and updating all the weights in back propogation using gradient descent is one Epoch
#
# **Iteration :** It happens inside one Epoch. If we have to do 20 Epoch and we have 10K dataset, Then while using SGD we use 1 dataset at a time so in 1 Epoch we have do 10K direction as we are using one record at a time. so 20 Epoch we have 20 * 10 K Iteration.

# %% [markdown]
# In **GD** as we take all data at once and if we 1 million records then its computationly expensive also it will be slow as loading so much also takes time.
#
# In **SGD** as we take one record at a time and each Epoch we have to Iteration = no of records hence even this slow.

# %% [markdown]
# GD loss function
#
# ![16.5%20GD%20loss.PNG](attachment:16.5%20GD%20loss.PNG)

# %% [markdown]
# SGD loss function
#
# ![16,5%20SGD%20loss.PNG](attachment:16,5%20SGD%20loss.PNG)

# %% [markdown]
# Mini batch loss function
#
# ![16.5%20Mini%20batch%20loss.PNG](attachment:16.5%20Mini%20batch%20loss.PNG)

# %% [markdown]
# In Mini Batch SGD if we have 1 10k record and we select size as 1k then in every epoch we will have to do 10 iterations ( front + back)
#
# ![16.5%20Mini%20batch.PNG](attachment:16.5%20Mini%20batch.PNG)
#
# **Advantages :**
#
#     * less resouces
#
#     * less computationally expensive

# %% [markdown]
# Lets compare the curve for GD and MSGD
#
# ![16.5%20GD%20Vs%20MSGD.PNG](attachment:16.5%20GD%20Vs%20MSGD.PNG)
#
# From the curve we know that MSGD will have a longer time and its had noise. So our Aim to reduce the noise i,e smothen the path.

# %% [markdown]
# ![16.5%20Momentum.PNG](attachment:16.5%20Momentum.PNG)
#
# IN order to smooten the noise we use Exponential Weighted Average.

# %% [markdown]
# ![16.5%20Momentum%20formula.PNG](attachment:16.5%20Momentum%20formula.PNG)
#
# If we set β = 0.95 then more value will be given to a1 but if we set it to 0.1 then it will give more value to current iteration a2.

# %% [markdown]
# The formual to calculate the weight and bias
#
# ![16.5%20EWA%20.PNG](attachment:16.5%20EWA%20.PNG)

# %% [markdown]
# ![16.5%20Implementation.PNG](attachment:16.5%20Implementation.PNG)

# %% [markdown]
# ![16.5%20Adagrad.PNG](attachment:16.5%20Adagrad.PNG)
#
# Intially we set a higher learning rate and reduce it after the itertaions/ Epoch proceeds. It faster as the intial steps are bigger as seen in the curve in blue.

# %% [markdown]
# below is the modification of the weight updation formula for Adagrad.
#
# ![16.5%20Adagrad%201.PNG](attachment:16.5%20Adagrad%201.PNG)

# %% [markdown]
# **Disadvantage :** We start our learning from 0.01 and when the interation increases the alpha t value becomes so high then thw learning rate so tiny that when we replace it in the weight update formula then new weight will be almost equal to old weight.
#
# ![16.5%20Adagrad%20Disadvantage.PNG](attachment:16.5%20Adagrad%20Disadvantage.PNG)

# %% [markdown]
# 5. AdaDelta or RMSPROP
#
# ![16.5%20RMSPROP.PNG](attachment:16.5%20RMSPROP.PNG)

# %% [markdown]
# ![16.5%20RMSPROP%20Implement.PNG](attachment:16.5%20RMSPROP%20Implement.PNG)

# %% [markdown]
# `![16.5%20Adam%20Optimzer.PNG](attachment:16.5%20Adam%20Optimzer.PNG)
#
# Adam Optimizer used both momentum and RMSPROP. WIth momentum we can smooten the noise and RMSPROP we could chnage learning rate.

# %% [markdown]
# ![16.5%20Adam%20Optimzer%20step%201.PNG](attachment:16.5%20Adam%20Optimzer%20step%201.PNG)

# %% [markdown]
# ![16.5%20Adam%20Optimzer%202.PNG](attachment:16.5%20Adam%20Optimzer%202.PNG)

# %% [markdown]
# **Bias Correction :** research came up to a concept of bias correction. SO the momentun and RMSPROP formula was corrected as shown below
#
# ![16.5%20Bias%20Correction.PNG](attachment:16.5%20Bias%20Correction.PNG)
