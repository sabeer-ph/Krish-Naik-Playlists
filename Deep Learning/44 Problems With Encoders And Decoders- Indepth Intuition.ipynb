# %% [markdown]
# ![44%20problem.PNG](attachment:44%20problem.PNG)
#
# Here discuss about problems with encoders and decoders.  We already how sequence to sequence learning with neural  networks  happens i.e about encoders  and decoders  in depth. then we also  understood about how to implement an  encoder and decoder  the best example that we took is neural  machine learning language translation, we tried to convert from  french to english use case.

# %% [markdown]
# The above image is taken from the [research paper](https://papers.nips.cc/paper/2014/file/a14ac55a4f27472c5d894ec1c3c743d2-Paper.pdf). On the left hand side we have Encoders and on the right we have decoders. output of Encoder "W" is given as input to decoder.

# %% [markdown]
# **Problem :** reserchers started expirementing with different size of senetences so the accuracy started decresing with more words in senetnces.

# %% [markdown]
# ![44%20Bleu%20Score.PNG](attachment:44%20Bleu%20Score.PNG)
#
# Best accuracy was achieved when sentence length was 10 more the words blue score decreased.

# %% [markdown]
# **Reason :** Since in Encoder we dont have output in each layer and just at end then output will not be able to capture the essense of all the words.

# %% [markdown]
# ![44%20Solution.PNG](attachment:44%20Solution.PNG)
