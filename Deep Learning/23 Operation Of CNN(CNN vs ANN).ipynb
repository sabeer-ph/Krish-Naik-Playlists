# %% [markdown]
# In this section we undersatnd the operations of CNN and the basic differences between an ANN and CNN operation.
#
# ![23%20ANN%20Vs%20CNN.PNG](attachment:23%20ANN%20Vs%20CNN.PNG)
#
# Left Side **ANN** and Right side **CNN**
#
# in ANN the every neuron in hidden layer does 2 things i.e adding weights with inputs and activation function. the finally the loss function is calculate. To recude the loss using optimzers the weights are updated during back propogation.
#
# similarly if we take the same  operation with respect to a CNN, we have some image, we can initialize some filters  it is used to find out the horizontal edge detection, vertical edge detection. Now the convolution operation says if I apply this  particular filter on to this image I'll  be able to get all the vertical edges in  the output image.
#
# Once we get the output image, what happens after this is particular stage is pretty much important to understand. we may also have another filter  like f2 horizontal edge  detection, f3 shape  detection.
#
# in ANN and we will try to update  this weight will try to learn this  weight with respect to the output in the backpropagation stage. Similarly in CNN will try to learn these filters and update the  values inside filter with the help of back propagation. After we get ouput in CNN we apply  relu activation function on each and  every field.
#
# The operation is almost same in ANN multiply the weights  with the inputs then apply an activation. IN CNN convolution  operation take filter apply convolution  operation get output and apply an activation function  each and every value. Right  after this we  vertically stack any number of  convolution. means diff filters
#
# A good term in  one of the research paper called location invariant. it says that  usually when our human brain sees some faces some of the neurons get automatically triggered. Similarly we should try to make our convolutional neural network also do that. Suppose in one image we have multiple cats faces then automatically this convolutional neural  network or the kernels that I'm  using should get automatically triggered where it will be able to detect those multiple faces. This step will be done by the **max pooling  layer**.
