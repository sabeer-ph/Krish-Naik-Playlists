# %% [markdown]
# First lets see using GD how do we reach global minina. the problem with GD is we load all data and if the data is very huge then it computation intensive.
#
# ![14%20GD.PNG](attachment:14%20GD.PNG)

# %% [markdown]
# WIth mini batch SGD we have noise data and it moves around the curve and it will take more time to reach the global Minima
#
# ![14%20SGD.PNG](attachment:14%20SGD.PNG)

# %% [markdown]
# So what do we do? we want to remove the noisy data and to achive it we use **Exponential Moving Average**. the removal of noisy data from SGD using Exponential Moving Average is called **SGD with Momentum**.

# %% [markdown]
# Next Lets see Mathamatically how do we do Exponential Moving average. Lets consider we have datas d1,b2....bn at time intervals t1,t2....tn
#
# ![14%20Moving%20Average.PNG](attachment:14%20Moving%20Average.PNG)
#
# Here we use γ (GAMMA) which is between 0 <  γ < 1
#
# so at V1 = b1
#
# and at v2 =  γ * v1 + b2 -->  γ * b1 + b2 ( if we consider  γ = 0.5 then b2 is still there but b1 is reduced by half)
#
# v3 =  γ * v2 + b3 -->  γ( γ b1 + b2) + b3 -->  γ^2b1 +  γb2 + b3 ( b3 is still there b2 reduces by half and b3 by 3/4th).
#
# so our noisy data (shown in black) will become more smooth (shown in blue)

# %% [markdown]
# SO how do we apply momentum in weight updation formula.
#
# ![14%20Weight%20Updation-2.PNG](attachment:14%20Weight%20Updation-2.PNG)
#
# **Note :** the  γ * Vt-1 is the momentum
