# %% [markdown]
# We will discuss about 2 main activation functions
#
#     * sigmoid
#     * ReLu  activation function
#
# In the previous selection we learned that there are 2 steps that happens in a hidden layer. There are differenct silutaions were will need to use diff activation function based on the output we need.
#
# ![03%20Steps%20in%20Hidden%20Neuron.PNG](attachment:03%20Steps%20in%20Hidden%20Neuron.PNG)

# %% [markdown]
# **sigmoid activation:** Is basically used in Logistic regression also. the formula of sigmoid  activation function show below and Y will be  basically the value of the weights  multiplied by the input features  +  bias and this particular Y is  basically transferred to this activation  function. i.e In the activation function formaula the Y will be replaced with the product of weights and the input feature plus  bias so once it is transformed this will  transform your value between **0 to 1**.
#
# ![03%20Sigmoid.PNG](attachment:03%20Sigmoid.PNG)
#
# let this product be any value negative,positive, big values this particular formula it will get transformed between 0 to 1. now one more point is if it is less than 0.5 we consider it 0. 0.5 is threshold if  it is greater than 0.5 output is 1.
#
#     * Output 0 means neuron not activated
#     * Output 1 means neuron activated
#
# The activated neuron means that it is actually transferring the signal to the next layer and is  actually helping you to classify a final output.

# %% [markdown]
# ![03%20ReLu.PNG](attachment:03%20ReLu.PNG)
#
# **ReLu activation function :** If our calculated y is passed though ReLu activation function a simple formula is applied to calculate the output **max(y,0)**. If Y is  negative applying the ReLu formual the output will always be zero and when Y is  positive and max(positive, zero) will be this positive number.
#
# **So when to use sigmoid and ReLU**
#
# whenever we are solving a regression problem statement most of the people try to use ReLU, let it be in hidden or output layers but if you are solving a classification problem in the middle layers we can use ReLu but on the final output layer we should always use sigmoid because the classification problems can be two/three categories classifying output and sigmoid does that main work it transform  the value between 0 to 1 and used for the classification problem statement.
