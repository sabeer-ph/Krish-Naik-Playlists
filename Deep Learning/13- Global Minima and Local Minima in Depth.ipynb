# %% [markdown]
# IN this section we will try to understand Global and Local Minima in depth
#
# ![13%20Global%20Minima.PNG](attachment:13%20Global%20Minima.PNG)

# %% [markdown]
# In the previous section we learned about GD, SGD and mini batch SGD. IN order to update the weights during back propogation we need to calculate the loss function. One of the loss function we leanred is mean square and the formula of mean square for mini batch SGD is show in the above figure.
#
# If our weight is on left side then we draw a tangent line and if the right side of the line is downwards then its -ve point. then to reach global minima we have to increase the weight and if the point on the right we have to decrease weight. Also One importand thing to understand is that the **derivative of global minima point is zero** (note minima or maximo derivative is zero)
#
# Like we have Minima we have a concept of Maxima but here in curve it doesnt apply as it doesnt have a point and continues.

# %% [markdown]
# Next lets say for example we choose a different type of loss function hence we get a diff curve the below shown curve is just example to understand local minima and maxima
#
# ![13%20Local%20Minima.PNG](attachment:13%20Local%20Minima.PNG)
#
# local minia is a minimal point in that locality but its not the glocal minima. ALso we have local maxima point. The derivative for all maxima and minima point is zero.
#
# **Problem** : Using the weight updating formula and when we reach a local maxima/minina the derivative part will become zero hence the new weight will be equal to old weight but the problem is we havent reach global minima. What do we do then? we need to use advanced optimizer techniques that will be discussed in nect section.

# %% [markdown]
# **saddle POint :**
#
# ![13%20Saddle%20Point.PNG](attachment:13%20Saddle%20Point.PNG)
#
# in the curves we might come across another point as shown in the figure called saddle point. If we calculate the slope/derivavtive of this point then it will be zero. Again same problem of not recahing global Minima.

# %% [markdown]
# **Next question is why do we have such curves? :** to understand 2 function convex function and non convex function.
#
# ![13%20Curves.PNG](attachment:13%20Curves.PNG)

# %% [markdown]
#     * convex function : mainly happens in machine learning for probems like linear and Logistic regression. in that case we get a bell like curve and we mark inside curve as area 1 and outside as area 2. if we have 2 points and we connect these 2 points if all the points in between falls in the same area. then there will be only 1 minima which is global.
#
#     * non convex function : mainly happens in Deep learning techniques where so many weight updating happens. the area above the curved is marked area 1 and below as area 2. if we have 2 points and joing these points will pass through both areas
