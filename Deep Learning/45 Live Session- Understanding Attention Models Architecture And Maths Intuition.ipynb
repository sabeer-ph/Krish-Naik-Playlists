# %% [markdown]
# The discussion is on [Reserch Paper](https://arxiv.org/pdf/1409.0473.pdf) which solves the problem of decrease accuracy with higher length sentences

# %% [markdown]
# ![45%20Sequence%20To%20Sequence.PNG](attachment:45%20Sequence%20To%20Sequence.PNG)
#
# SO we have already understand how sequence to sequecne works and the role of Encoders and Decorders. We also know the **problem** we have that is the longer the sentence the lower the accuracy. The reason for this is that we have only one output from encoder that happends at the <EOS> (End of statement) and this vector |W| cannot represnt the full sentence when the words are more.

# %% [markdown]
# The **solution** for this as per the research paper is to use Biderctional RNN/LSTM in the encoder.
#
# ![45%20Solution.PNG](attachment:45%20Solution.PNG)

# %% [markdown]
# ![45%20General.PNG](attachment:45%20General.PNG)

# %% [markdown]
# Here Tx is the window time where no of words is read and translated.
#
# **h :** is the output from the encoder.
#
# **C1 :** is the input to Decoder.
#
# to comvert h to C1 we use Feed forward NN.
#
# aplha1, 2 3..n are weights and their summation should be = 1
