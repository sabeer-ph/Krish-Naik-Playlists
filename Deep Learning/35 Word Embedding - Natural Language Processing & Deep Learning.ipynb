# %% [markdown]
# Suppose we want  to do a sentiment analysis for the text  data and we can efficiently use  this embedding layer which is available  in **Keras** but before that we need to understand what is exactly word embedding.

# %% [markdown]
# We have already learnt about bag of words (BOW) and tf-idf. We have seen BOW representation and also  understood the disadvantage that we will not be getting much semantic information. In tf-idf very little semantic information we will be getting.
#
# Now, the third technique just to overcome this particular disadvantages will be using something called as **word embedding**. In word embedding there are two techniques **1) Word2Vec** **2)glove**.
#
# We have already covered **Word2Vec**. let's understand what  exactly is embedding technique and how  we are actually overcoming the  disadvantage of TF-IDF. the most important thing in  NLP is basically the text pre-processing  converting this text data into some  vector representation so that the  algorithm will be able to generalize these words to do any kind of predictions  or to do any kind of sentence generation  and many more things.
#
# so let's let's go ahead and try to first of all understand some important or basic terms  with respect to word representation.

# %% [markdown]
# Lets consider we have a dictionary |V| which contains 10000 words and we have words Man and Women at index 5000 and 9000. If we convert this dictionary using One Hot Representation it will be as below.
#
# ![35%20Word%20Rep.PNG](attachment:35%20Word%20Rep.PNG)
#
# **Problem with One Hot Representation :** When we apply machine/Deep learning models on these vectors if will be hard to generalize. Since in a vector we will have more zeros and less 1's hence its also hard to find similar words and also no much semantics. this is a sparse matrix (**it means the matrix has more zeros and less 1's**)

# %% [markdown]
# In order  to overcome this particular disadvantage there is a concept called as **word embedding** and in word embedding there is a concept of **feature representation**.

# %% [markdown]
# ![35%20Word%20Embedding.PNG](attachment:35%20Word%20Embedding.PNG)
#
# considering this words  like boy girl king queen apple mango we will try to convert them into vectors based on some features. some features are like  gender royal age food etc etc somewhere like 300 features.
#
# **1st Row :** Feature is Gender hence its realated boy, girl, king and Queen and the values are high for these and not mango and apple.
#
# **2nd Row :** Royal feature is related to only king and queen and the values are high for them and rest are negligible/

# %% [markdown]
# **Advantage :** As we have taken only 300 features on which the matrix is created we have **Low Dimesnion** and **Dense Matrix**.

# %% [markdown]
# **Uses :** We can find the analogy of words like Boy tends to girl what will King analogy be ?
#
# ![35%20Analogy.PNG](attachment:35%20Analogy.PNG)
#
# Subracting 2 vectors we can understand the analogy of words.

# %% [markdown]
# One more intresting this is if we convert this vectors of 300 dimension to 2D we will get to see that similar kinds of words will be plotted near to each other where it can be grouped.
#
# ![35%202d%20Word%20%20Rep.PNG](attachment:35%202d%20Word%20%20Rep.PNG)
