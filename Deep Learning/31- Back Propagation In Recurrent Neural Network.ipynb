# %% [markdown]
# In back propagation what we do is that after we calculate our loss function, in the back propagation we update this weights and
# the updation of these weights is important because of that only we will be able to reach a gradient descent a global minima in the particular gradient descent.

# %% [markdown]
# ![30%20RNN%20Whole%20Architecture.PNG](attachment:30%20RNN%20Whole%20Architecture.PNG)

# %% [markdown]
# this is our forward  propagation we calculated **y hat** and **loss function**. now the main aim  is to reduce this loss function now in  order to reduce the loss function in back propagation first we have to find out the derivative of loss with respect to  derivative of Y hat will get calculated (delta L / Delta y Hat).  Once this is calculated next is the technique of updating these weights.

# %% [markdown]
# Weights can  be updated by two ways
#
# first of all this  w'' is basically dependent on Yi hat (input and output of softamx function). I had  so first of all if I want to calculate  derivative of loss with respect to  derivative of W double dash (delta L /delta w'') . with the help of chain rule we can rewrite it as derivative of loss with the derivative  of Yi hat dot d Yi hat x derivative to w''  (d L / d yi hat * d yi hat / d w'' ).
#
# with the help of  simple chain rule we will find w'' and then this  derivative will get subtracted  with derivative of loss with the derivative  of w''   (w'' = w'' - (d L / d w'')). so we update the value for w''
#
# ![31%20RNN%20w''.PNG](attachment:31%20RNN%20w''.PNG)

# %% [markdown]
# Next for time = 4 we have 2 weights w' and w.
#
# we have  actually found out a derivative of W  double hat right now we will try to find  out the derivative of W because we need  to update this also.
#
# ![31%20RNN%20t4%20w'.PNG](attachment:31%20RNN%20t4%20w'.PNG)

# %% [markdown]
# this is how a chain rule will get  created well each and every W is getting  updated and this is how the back  propagation of gets applied ok now when  the back propagation is getting applied  all we are just doing is that we are  just finding the derivative and they are  updating this weights that's it.
#
# we are just updating this weights and as  soon as we find out derivative which is  actually a slope  we'll be able to find out the weights  will update the weights and this will be  going on for many alterations
