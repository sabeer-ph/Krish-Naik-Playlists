# %% [markdown]
# Here we will try to understand the problems with the simple RNN.

# %% [markdown]
# ![32%20simple%20RNN.PNG](attachment:32%20simple%20RNN.PNG)

# %% [markdown]
# WE have created this RNN in which we are doing a forward propagation  and backward propagation over time and when you are doing the  backward propagation in time the  derivative of this weights gets updated continuously with respect to time.
#
# At T = 4 respective W will get updated at T = 3 its respective W will get updated and  this will make sure that whatever these  are dependent on those it will take the  chain rule of all those things. so considering chain rule  with respect to derivative it will get  calculated but when it is getting  calculator understand  about vanishing gradient problem and exploding gradient problem

# %% [markdown]
# ![30%20RNN%20Architecture.PNG](attachment:30%20RNN%20Architecture.PNG)

# %% [markdown]
# so when we consider this hidden  layer they are neurons inside this, we apply an activation function and most  common activation function that you  basically apply is sigmoid,ReLu activation function.
#
# now understand what is  vanishing gradient problem, when we do a backward  propagation with respect to this weights  and if you have applied inside the  scenario neurons some activation  functions like sigmoid if we find out  the derivative of a sigmoid it will  always be between 0 to 1. now suppose t = 3 we have calculated  derivative function it will between the 0 to 1 but as we go  towards t=1  W  value becomes very small as the derivative is continuously  happening.
#
# we find out the  derivative of all these particular  weights this will become a very very  small value now when it becomes a very  very small  whenever we do an updating of this weights it would be  negligible. when it is negligible we  will never converge to the global minimum point of  a gradient descent.

# %% [markdown]
# ![32%20VGP.PNG](attachment:32%20VGP.PNG)

# %% [markdown]
# so if I gradient  descent is like above. now suppose  this is my initial point there'll be a  small movement over here again I will be  coming here but it will never reach at  this particular point you know because  of that this is basically called as  **vanishing gradient problem**.

# %% [markdown]
# if you are using other activation function  which is other than sigmoid like a  regular activation function and suppose derivative is greater than one. Again it may be getting so many  derivatives later on with greater than  one so as we go ahead towards this it  creates a **exploding gradient problem**.
#
# Exploding gradient problem  basically means that **W** changes will happen so big that it will  never reach the global minimum it will  be rotating here itself. because the  value of the change of the **W** is very  very high it'll never reach this global  minima.

# %% [markdown]
# So because of this particular problem we use a simple architecture called as **LSTM (long short term memory)** we use this particular  architecture in order to solve that particular problem.
