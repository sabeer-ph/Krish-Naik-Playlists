# %% [markdown]
# [Attention is all you need](https://papers.nips.cc/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf) research paper
#
# [jalammar blog](https://jalammar.github.io/illustrated-transformer/) which explains transfomers with visulization.
#
# his [blog](https://jalammar.github.io) has many others topics as well.

# %% [markdown]
# Krish goes throught the jay blog to exaplin about tranfomrers. I am not pasting all pictures just few pictures

# %% [markdown]
# Step 1 inside Self attention layer (for example only 2 words taken)
#
# ![48%20Self%20attention%20step%201.PNG](attachment:48%20Self%20attention%20step%201.PNG)

# %% [markdown]
# Step 2:
#
# ![48%20Self%20attention%20step%202.PNG](attachment:48%20Self%20attention%20step%202.PNG)

# %% [markdown]
# STep 3 & Step 4
#
# ![48%20Self%20attention%20step%203%20&%204.PNG](attachment:48%20Self%20attention%20step%203%20&%204.PNG)

# %% [markdown]
# Step 5
#
# ![48%20Self%20attention%20step%205.PNG](attachment:48%20Self%20attention%20step%205.PNG)
#
# Here Z1 = 0.88 * V1 + 0.88 * v2

# %% [markdown]
# ![48%20formula%20step%202%20to%206.PNG](attachment:48%20formula%20step%202%20to%206.PNG)

# %% [markdown]
# So far what we did is called **single headed attention** the reason is that we have used the same weights Wq, Wk and Wv.
#
# If we use different weights then it becomes **multi headed attention**.

# %% [markdown]
# ![48%20Multi%20headed.PNG](attachment:48%20Multi%20headed.PNG)
