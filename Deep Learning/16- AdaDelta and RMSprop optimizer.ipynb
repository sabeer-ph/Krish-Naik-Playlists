# %% [markdown]
# AdaDelta and RMSprop optimizer are somewhat same but done by 2 different team of people. Before understading them lets recap on Adagrad.
#
# ![16%20Adagrad%20recap.PNG](attachment:16%20Adagrad%20recap.PNG)
#
# As the iteration increases the learning rate decreases. But the problem is as the neural becomes very deep then ∝t increases and becomes very high value and then learning rate become negligible then Wnew = Wold

# %% [markdown]
# As mentioned AdaDelta and RMSprop optimizer are same and the idea not have a high number in the denominator.
#
# ![Adadelta%20&%20RMSprop.PNG](attachment:Adadelta%20&%20RMSprop.PNG)
