# %% [markdown]
# In this  particular topic particular session will  be discussing how neural network works  in our previous session we have already  seen the architecture of a basic neural  network but in this session we'll  understand how the network works.
#
# this particular video in many parts  because I have to explain you the  forward propagation what happens in the  forward propagation and then I discuss  about what is an activation function and  after that what happens in the backward  propagation and what are the key terms  like cost function loss function.
#
# So in the previous section we have already discussed what is the basic architecture would take the same example.
#
# ![02%20Neural%20Network%20Working.PNG](attachment:02%20Neural%20Network%20Working.PNG)

# %% [markdown]
# We are trying to solve a binary classification problems in the input layer We  have three features like **x1 x2 x3** that is getting passed to the hidden neuron. the neuron in the hidden layer does some processing and we will understand what kind of  processing it does and what are lines with weights (W1,W2,W3) specify.
#
# Once the inputs (X1,X2,X3) along with the weights (W1,W2,W3) reaches the hidden layer neuron  there are two  types of operation that usually happens  inside
#
# ![02%20Steps%20in%20Hidden%20Neuron.PNG](attachment:02%20Steps%20in%20Hidden%20Neuron.PNG)
#
#  * So in our case step 1 is y = X1W1 + X2W2 + X3W3 . Also we will add bias value to it so it becomes  X1W1 + X2W2 + X3W3 + Bias
#  * step 2 : is applying an activation function on step 1 i.e  z = Activation(y)
#
# The activation  function and the weights play a very  very important tool.
#
# let just give you an example for **activation function** suppose we have kept a hot object in my hand as soon as that signal  that information will get passed through  these neurons so in short this neurons are getting activated why it is getting  activated because the hot object is  placed. This neurons get activated  with the help of higher weights.

# %% [markdown]
# if I take an example of one kind of activation function Sigmoid the  equation is something given below
#
# ![02%20Sigmoid.PNG](attachment:02%20Sigmoid.PNG)
#
# When our calculated value y passes throught sigmoid the output will be either 0 or 1. if the value is  less than 0.5 it becomes 0 that  basically means this neuron will not  get activated. if it is greater than  0.5 the neurons get activated.
#
# So this is the basic  neural network that is how a neural  network works and this  propagation is basically called **forward propagation** . In our case the output of hidden neuron "Z" and when this is passed to the output layer again a weight **(W4)**. Suppose this is the classification problem then we should be either getting 0 or 1 then in that case activation function will be applied on Activation(z*w4).
#
# In  this example we have just taken one  neuron in the hidden layer but we can have any number of neurons and it will all be doing the same process.
