# %% [markdown]
# In this we will try to understand slope, derivative in depth

# %% [markdown]
# Lets underatnd the naming convention used in the above picture
#
# * Input layer to the first hidden layer weights will be w11 with a 1 on the top.
# * the neurons in the first hidden layer are named f11, f12, f13
# * the output from these hidden layer are named O11, O12, O13
# * the weights from the first hidden layer to the second hidden layer is named W11 with 2 on top.
# * the two neurons in the second hidden layer are named f21, f22.
# * the output from these neurons are O21, O22.
# * the weights from second hidden layer to output layer is W11 with 3 on top.
# * the output layer is named f31
# * the output from this node is O31 which is also our y^.
#
# Once we get out y* we calulate the loss function then we try to reduce the loss. we use optimizer and we start updating the weights in the reverse direction during back propogation.

# %% [markdown]
# So lets start upadting weight for our example. so how do we calculate the new weight for W11^3. The formula is below
#
# ![06%20New%20weight-2.PNG](attachment:06%20New%20weight-2.PNG)

# %% [markdown]
# SO IN order to calculate W11^3 we need to know the derivative. We know that the weight W11^3 impacts the output O31 so with the help of **chain rule** with can rewrite the derivative as shown above.
#
# Similarly if we want to calculat the new weight for W11^2 then it deponds on both output O21 and O31. The derivavtive formula is as shown below.
#
# ![06%20New%20weight%20w11%202.PNG](attachment:06%20New%20weight%20w11%202.PNG)
#
# but the above formuala is just not enough as this first neuron from the first hidden layer is connected to 2 neurons from the 2nd hidden layer. Hence the formula gets added as below.

# %% [markdown]
# ![06%20New%20weight%202%20neuron.PNG](attachment:06%20New%20weight%202%20neuron.PNG)
#
# IN general if we want to calculate the new weight for any particular point we need see how many paths are going towards the final output then caculate  path1+ path2 + path3 and so on.
#
# 1 epoch means 1 forward + 1 backward propogation
