# %% [markdown]
# ![38%20Information%20Gain.PNG](attachment:38%20Information%20Gain.PNG)

# %% [markdown]
# Infomation Gain : is used to know using which feature if we do a split it will be good.
#
# So in the formuala H(s) is the sample Entropy before the split.
#
# H(Sv) is the entropy after the split in this cases f2,f3.
#
# So here also we have taken the same example as Entropy 9 YES and 5 No.
