# %% [markdown]
# ![27%20Case%20Study.PNG](attachment:27%20Case%20Study.PNG)

# %% [markdown]
# Lets consider we have 2 points in our training dataset and we find a best fit line which pases through both the points. If we calcuate the cost function the output we be zero.
#
# When we test this model on our test dataset we get a high cost function. The problem here is we built a model which is not generalized in other ways we say the model is overfitting.
#
# **Overfitting :** With the test dataset the model gives best resuts with less or zero error. but its doesnt do well with the test dataset.
#
# **UnderFitting :** the model doesnt do well with both training and test dataset.
#
# Any model we build should have low bias and low variance.

# %% [markdown]
# #### Lets understand how does Ridge Regression help us to solve this problem. But lets first understand the working of Ridge.

# %% [markdown]
# So the main difference between the linear and Ridge regression is the formula. Where in Ridge we have additonal lambda * (slope)^2.

# %% [markdown]
# So in the above case where we got a best fit line and the cost function was zero. Here we will get a value greater than zero and we try to reduce to reduce . This addition to the formual reduces the steepness of the slope trying to make it a generalized model.

# %% [markdown]
# ![27%20Ridge.PNG](attachment:27%20Ridge.PNG)

# %% [markdown]
# Here is lambda should be a positive value greater than zero and its ideal value is found using crossvalidation.

# %% [markdown]
# ### Lasso Regression :

# %% [markdown]
# Here again the main difference is the formula instead of slope^2 its magnitude of slope.
#
# ![27%20Lasso.PNG](attachment:27%20Lasso.PNG)

# %% [markdown]
# The advanatge of Lasso is that its not only helps us with the overfitting problem but its also helps in feature selection. In lasso we try the reduce the steepness of the slope and tend to move it to get the slope =0 , in such cases features with not much importance magnitude will also be zero.
