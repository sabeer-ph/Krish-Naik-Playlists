# %% [markdown]
# We will try to understand how to use Naive Bayes theorm on text data. Using text we might have problems statements like good or bad review, spam or not.

# %% [markdown]
# When we have text data we do lot of intial preprocessing like remove stopwordss, stemming/lemmatization, Bag of Words/TD IDf.

# %% [markdown]
# SO if we have a setence, we can consider each words inside it as x1,x2..xn (after pre  processing). So we find the probabilty that our output is yes given the words.

# %% [markdown]
# ![v81%20Naive%20Bayes.PNG](attachment:v81%20Naive%20Bayes.PNG)

# %% [markdown]
# The idea is first we will calculate the probabilty ( y = yes | sentence) and then ( y = no | sentence). And then normalize the yes value to get its percentage (yes/yes+no) and to get percentage of no we do 1- (yes/yes+no)

# %% [markdown]
# some highights
#
# P(y = yes ) # count of y(o/p) when its 1 out of total output. we have 2 1's and total sentence is 5 so 2/5
#
# p(x1 | y = yes)  # x1 is word "the".  so it means count of "the" word when output is 1 by total the word. we have 1 "the" word
#  when output is 1 and we 2 "the" words so 1/2.
