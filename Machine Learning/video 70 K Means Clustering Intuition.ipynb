# %% [markdown]
# ![v70.PNG](attachment:v70.PNG)

# %% [markdown]
# Step 1: We select a K value, lets say 2 (best value of K is selected using elbow method which is discussed later).
#
# step 2: randomly select the centriods . In this case 2 centroids.
#
# Step 3: draw 2 lines , one joining the 2 points and other perpendicular. Anything above the perpendicular line belongs to one centroid and below to second centroid. calculate the mean of one group and move the centroid to that point. And redo step 3 until the points dont change group.

# %% [markdown]
# **Best Value of K :**
#
# ![v70%20Elbow%20.PNG](attachment:v70%20Elbow%20.PNG)

# %% [markdown]
# So we take K value from 1 to 20 and do the clustering and for each clustering we calculate the **within cluster square sum** and plot it on the graph. For K=1 WCSS is high and it will reduce as the K value increases until a point the changes are minute. We select that value of K as best.
