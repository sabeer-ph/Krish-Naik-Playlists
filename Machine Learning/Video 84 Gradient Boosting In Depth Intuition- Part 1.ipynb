# %% [markdown]
# ![v84%20base%20model.PNG](attachment:v84%20base%20model.PNG)

# %% [markdown]
# We have a dataset where our independent features are Exp and Degree and the dependent feature is Salary.
#
# Step 1: Is we compute a base model and we calcuate our predicted output (y^) which is the average of all the dependent feature which is 75.
#
# Step 2: Calcuate the residue by subrcting salary - y^
#
# step 3: We construct a Decision Tree using our inputs EXp and Degree and the residue from the base model. So lets say we got 52 which is aproximetaley equal to our actual value. **this is overfitting problem**.
#
# SO as usual we introduce **learning rate**

# %% [markdown]
# 75 + aplha (R2)
#
# **Aplha value varies from 0 to 1**
#
# 75 + 0.1 * (-23) = 73.57

# %% [markdown]
# ![v84%20FInal.PNG](attachment:v84%20FInal.PNG)

# %% [markdown]
# So we keep adding decision tree with our inputs and the output from the previous Decision tree. Hence the above formula.
