# %% [markdown]
# Euclidean Distance and Manhattan Distance is used in K nearest neighbor (KNN) and also in unsupervised learning technques like K means clustering and Heirachial Means clustering.

# %% [markdown]
# both these techniques are used to calculate the distance between 2 points.

# %% [markdown]
# **Euclidean Distance : 2D**
#
# ![v69.PNG](attachment:v69.PNG)
#
# Distance between points A and C can be calcuated using pythogors theorm AC^2 = AB^2 + BC^2

# %% [markdown]
# **3D :** the points will become x1,y1,z1 and x2,y2,z2
#
# ![v69%203D.PNG](attachment:v69%203D.PNG)

# %% [markdown]
# **Manhattan Distance :** in order to calculate the distance between A to C we add AB + BC.
#
# ![v69%20Manhattan.PNG](attachment:v69%20Manhattan.PNG)

# %% [markdown]
# for machine learning we need to try both and do hyperparameter tuning
