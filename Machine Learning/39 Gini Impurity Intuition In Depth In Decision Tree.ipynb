# %% [markdown]
# Both Gini Impurity and Entropy is used to calculate the purity of the split but most times Gini Impurity is better than Entropy.

# %% [markdown]
# Gini Impurity is computationally faster compared to Entropy coz of its formula as ENtropy has to calculate the log values.

# %% [markdown]
# ![39%20Gini%20Impurity.PNG](attachment:39%20Gini%20Impurity.PNG)

# %% [markdown]
# As shown in the graph entropy max value is 1 and gini impurity max value is 0.5.
