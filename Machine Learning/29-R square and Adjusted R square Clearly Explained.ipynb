# %% [markdown]
# In Supervised Learning we have 2 types.
#
#         1.Classification : to evaluate accuracy we use metrics like accuracy score, confusion matrix, true postive, false positive, precision rate, recall value, F1 score.
#         2. Regression : We use R squre and Adjusted R square.

# %% [markdown]
# ![29%20SSres.PNG](attachment:29%20SSres.PNG)

# %% [markdown]
# ![29%20SStotal.PNG](attachment:29%20SStotal.PNG)

# %% [markdown]
# Caculating the R^2 we get a value between 0 and 1. more the value is near to 1 means the model is a best fit. in other words R^2 tells us the goodness of the best fit line.

# %% [markdown]
# #### Adjusted R^2

# %% [markdown]
# ![29%20Adjuested%20R%5E2.PNG](attachment:29%20Adjuested%20R%5E2.PNG)

# %% [markdown]
# As we add more and more features the liner regression alogorith will select the coefficient for the feature such that the value of SSres is the lowest. When this value and SStot is very small 1-SSres/SStot will give a hight values.
#
# So as we add more and more features then the R^2 value keeps increasing even if the feature we add its not corelated to the output. In such cases we used Adjusted R^2 value.

# %% [markdown]
# ![29%20Adjuested%20R%5E2%20formual.PNG](attachment:29%20Adjuested%20R%5E2%20formual.PNG)

# %% [markdown]
# So if we increase the P value(No of Features) then the demoninator becomes smaller value then the whole division gives higher value then 1 - this value gives a small value.
#
# But when we add new feature which is corealted to the output then the R^2 value in the nominator is high then 1- this value is small value. SO in total we get a high value.
#
# Adding not corelated fetaures will reduce the R^2 adjuested.
#
# Note : R^2 is always less than or equal to R^2.

# %% [markdown]
# ![29%20Diff.PNG](attachment:29%20Diff.PNG)
